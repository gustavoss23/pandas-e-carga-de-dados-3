# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

r = requests.get(url)

data_json = r.json()

df = pd.DataFrame(data_json['items'])

df
# Out:
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# 0          5069        Município                  Nova Veneza   5215009  GO
# 1          5093        Município               Venâncio Aires   4322608  RS
# 2          5061        Município                     Campinas   3509502  SP
# 3          5810        Município                      Flórida   4108106  PR
# 4          5815        Município                Lagoa do Ouro   2608602  PE
# ...         ...              ...                          ...       ...  ..
# 4995      45890        Município  São Sebastião da Bela Vista   3164407  MG
# 4996      42191        Município               Rosário do Sul   4316402  RS
# 4997      38896        Município     São Gonçalo do Rio Preto   3125507  MG
# 4998      34540        Município                      Ipanema   3131208  MG
# 4999      43833        Município                Florianópolis   4205407  SC
#
# ...

# %%
df_rj = df[df['uf'] == 'RJ']

df_rj
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 30         5618        Município          Nova Iguaçu   3303500  RJ
# 77         7080           Estado       Rio de Janeiro        33  RJ
# 105        5275        Município       Rio de Janeiro   3304557  RJ
# 136        6445        Município              Resende   3304201  RJ
# 140       60354        Município               Paraty   3303807  RJ
# ...         ...              ...                  ...       ...  ..
# 4587      68758        Município             Mesquita   3302858  RJ
# 4589      68813        Município       Rio de Janeiro   3304557  RJ
# 4622      10226        Município  Conceição de Macabu   3301405  RJ
# 4647      13634           Estado       Rio de Janeiro        33  RJ
# 4723      10281        Município       Rio de Janeiro   3304557  RJ
#
#                    num_pvl                                             status  \
# ...

# %%
# 2) Seu código aqui

df_rj['status'].value_counts()
# Out:
# status
# Deferido                                                 26
# Encaminhado à PGFN com manifestação técnica favorável    10
# Deferido (PVL-IF)                                        10
# Arquivado                                                 9
# Arquivado por decurso de prazo                            5
# Arquivado a pedido                                        3
# Regularizado                                              2
# Em retificação pelo interessado                           1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui

df_rj['ano'] = df_rj['data_status'].str.extract('(\d{4})')

df_rj['ano']
# Out:
# C:\Users\gusta\AppData\Local\Temp\ipykernel_15280\3083127685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rj['ano'] = df_rj['data_status'].str.extract('(\d{4})')
# 30      2010
# 77      2012
# 105     2014
# 136     2013
# 140     2022
#         ...
# 4587    2024
# 4589    2024
# 4622    2008
# 4647    2002
# 4723    2008
# Name: ano, Length: 66, dtype: object

# %%
# 4) Seu código aqui

df_rj['ano'].value_counts()
# Out:
# ano
# 2022    7
# 2008    6
# 2019    6
# 2023    6
# 2012    5
# 2013    5
# 2020    5
# 2009    4
# 2010    4
# 2014    3
# 2018    3
# 2024    3
# 2007    2
# 2011    2
# 2002    2
# 2017    2
# 2015    1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def dados_consulta(uf, tipo_interessado):
    consulta = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return consulta

# %%
# 2) Seu código aqui
uf_mg = 'MG'
tipo_interessado_mg = 'Estado'
consulta_mg = dados_consulta(uf_mg, tipo_interessado_mg)

consulta_mg
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 982        9197           Estado  Minas Gerais        31  MG    None
# 1520       6917           Estado  Minas Gerais        31  MG    None
# 2102       6811           Estado  Minas Gerais        31  MG    None
# 2636      10011           Estado  Minas Gerais        31  MG    None
# 4310      13595           Estado  Minas Gerais        31  MG    None
#
#                                                  status          num_processo  \
# 982   Encaminhado à PGFN com manifestação técnica fa...  17944.000924/2009-03
# 1520  Encaminhado à PGFN com manifestação técnica fa...  17944.000458/2012-53
# 2102  Encaminhado à PGFN com manifestação técnica fa...  17944.000435/2008-62
# 2636                                           Deferido  17944.001099/2010-90
# 4310                                         Indeferido  19405.000033/2002-03
#
#             data_protocolo                                      tipo_operacao  \
# ...

# %%
consulta_mg['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    3
# Deferido                                                 1
# Indeferido                                               1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_ba = 'BA'
tipo_interessado_ba = 'Município'
consulta_ba = dados_consulta(uf_ba, tipo_interessado_ba)

consulta_ba
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 5          5823        Município       Barra do Choça   2902906  BA
# 18         5693        Município             Mansidão   2920452  BA
# 42         7069        Município               Mucugê   2921906  BA
# 159       68078        Município                 Caém   2905107  BA
# 165       68489        Município   Brotas de Macaúbas   2904506  BA
# ...         ...              ...                  ...       ...  ..
# 4788      40308        Município               Coribe   2909109  BA
# 4812      40491        Município           Nordestina   2922656  BA
# 4861      68549        Município     Cardeal da Silva   2907004  BA
# 4864      63552        Município  Teixeira de Freitas   2931350  BA
# 4870      66415        Município    Ribeira do Pombal   2926608  BA
#
#                    num_pvl                          status  \
# 5                     None  Arquivado por decurso de prazo
# ...

# %%
status_deferido_ba = consulta_ba[consulta_ba['status'] == 'Deferido']

status_deferido_ba
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 18         5693        Município                Mansidão   2920452  BA
# 42         7069        Município                  Mucugê   2921906  BA
# 343       31108        Município                Salvador   2927408  BA
# 374        6102        Município                  Mucuri   2922003  BA
# 401        6771        Município             Baianópolis   2902500  BA
# ...         ...              ...                     ...       ...  ..
# 4692      58449        Município         Morro do Chapéu   2921708  BA
# 4740      10327        Município  Luís Eduardo Magalhães   2919553  BA
# 4745      62489        Município         Morro do Chapéu   2921708  BA
# 4864      63552        Município     Teixeira de Freitas   2931350  BA
# 4870      66415        Município       Ribeira do Pombal   2926608  BA
#
#                    num_pvl    status          num_processo  \
# ...

# %%
status_deferido_ba_minicipio = status_deferido_ba['interessado'].value_counts()
status_deferido_ba_minicipio.head()
# Out:
# interessado
# Luís Eduardo Magalhães    3
# Oliveira dos Brejinhos    3
# Morro do Chapéu           3
# Boa Vista do Tupim        2
# São Sebastião do Passé    2
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
uf_ba = 'BA'
tipo_interessado_ba = 'Estado'
consulta_ba = dados_consulta(uf_ba, tipo_interessado_ba)
consulta_ba
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 503       64646           Estado       Bahia        29  BA
# 962       22572           Estado       Bahia        29  BA
# 992       23723           Estado       Bahia        29  BA
# 1038      18633           Estado       Bahia        29  BA
# 1082      19016           Estado       Bahia        29  BA
# 1113      18495           Estado       Bahia        29  BA
# 1135      18372           Estado       Bahia        29  BA
# 1137      18527           Estado       Bahia        29  BA
# 1608      18535           Estado       Bahia        29  BA
# 2018      68346           Estado       Bahia        29  BA
# 2203       6334           Estado       Bahia        29  BA
# 3053      69073           Estado       Bahia        29  BA
# 3704       8535           Estado       Bahia        29  BA
# 3852      13126           Estado       Bahia        29  BA
# 4187      10855           Estado       Bahia        29  BA
# ...

# %%
consulta_ba.to_csv('Solicitações_BA_Estado.csv')
